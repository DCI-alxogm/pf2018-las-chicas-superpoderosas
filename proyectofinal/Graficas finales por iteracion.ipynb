# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
datos=np.loadtxt('itera1.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('1')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera2.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('2')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera3.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('3')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera4.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('4')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera5.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('5')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera6.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('6')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera7.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('7')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera8.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('8')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera9.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('9')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera10.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('10')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera11.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('11')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera12.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('12')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera13.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('13')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera14.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('14')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera15.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('15')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera16.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('16')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera17.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('17')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera18.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('18')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos=np.loadtxt('itera19.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('19')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()
