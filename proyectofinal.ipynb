# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
data1=np.loadtxt('resultadosjupiterchidos.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x1=data1[:,0:1]
y1=data1[:,1:2]
z1=data1[:,2:3]


ax.scatter(x1,y1,z1, c='b', marker='o')
plt.title('jupiter')
plt.show()

# %%
#prueba de grafica en 3D
##borrar 

fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
X= np.arange(-4, 4, 0.25)
Y= np.arange(-4, 4, 0.25)
X, Y =np.meshgrid(X,Y)
R=np.sqrt(X**2 + Y**2)
Z=np.sin(R)
plt.title('grafica de prueba')
ax.plot_surface(X,Y,Z, rstride=1,cstride=1, cmap='hot')

# %%
data=np.loadtxt('iniciales.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=data[:,0:1]
y=data[:,1:2]
z=data[:,2:3]

ax.scatter(x,y,z, c='r', marker='o')
plt.title('Posiciones iniciales')
plt.show()

# %%
data2=np.loadtxt('resultadostierra.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x2=data2[:,0:1]
y2=data2[:,1:2]
z2=data2[:,2:3]
plt.title('Tierra')
ax.scatter(x2,y2,z2, c='g', marker='o')
plt.show()

# %%
data3=np.loadtxt('resultadosmercurio.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x3=data3[:,0:1]
y3=data3[:,1:2]
z3=data3[:,2:3]
plt.title('Mercurio')
ax.scatter(x3,y3,z3, c='r', marker='o')
plt.show()

# %%
data4=np.loadtxt('resultadosvenus.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x4=data4[:,0:1]
y4=data4[:,1:2]
z4=data4[:,2:3]
plt.title('Venus')
ax.scatter(x4,y4,z4, c='pink', marker='o')
plt.show()

# %%
data5=np.loadtxt('resultadosmarte.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x5=data5[:,0:1]
y5=data5[:,1:2]
z5=data5[:,2:3]
plt.title('Marte')
ax.scatter(x5,y5,z5, c='orange', marker='o')
plt.show()

# %%
data6=np.loadtxt('resultadossaturno.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x6=data6[:,0:1]
y6=data6[:,1:2]
z6=data6[:,2:3]
plt.title('Saturno')
ax.scatter(x6,y6,z6, c='yellow', marker='o')
plt.show()

# %%
data7=np.loadtxt('resultadosurano.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x7=data7[:,0:1]
y7=data7[:,1:2]
z7=data7[:,2:3]
plt.title('Urano')
ax.scatter(x7,y7,z7, c='purple', marker='o')
plt.show()

# %%
data8=np.loadtxt('resultadosneptuno.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x8=data8[:,0:1]
y8=data8[:,1:2]
z8=data8[:,2:3]
plt.title('Neptuno')
ax.scatter(x2,y2,z2, c='black', marker='o')
plt.show()

# %%
data9=np.loadtxt('resultadospluton.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x9=data9[:,0:1]
y9=data9[:,1:2]
z9=data9[:,2:3]
plt.title('Pluton')
ax.scatter(x9,y9,z9, c='magenta', marker='o')
plt.show()

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x1=data1[:,0:1]
y1=data1[:,1:2]
z1=data1[:,2:3]

x2=data2[:,0:1]
y2=data2[:,1:2]
z2=data2[:,2:3]

x3=data3[:,0:1]
y3=data3[:,1:2]
z3=data3[:,2:3]

x4=data4[:,0:1]
y4=data4[:,1:2]
z4=data4[:,2:3]

x5=data5[:,0:1]
y5=data5[:,1:2]
z5=data5[:,2:3]

x6=data6[:,0:1]
y6=data6[:,1:2]
z6=data6[:,2:3]

x7=data7[:,0:1]
y7=data7[:,1:2]
z7=data7[:,2:3]

x8=data8[:,0:1]
y8=data8[:,1:2]
z8=data8[:,2:3]

x9=data9[:,0:1]
y9=data9[:,1:2]
z9=data9[:,2:3]

plt.title('Planetas')
        
ax.scatter(x1,y1,z1,c='b' ,marker='o')
ax.scatter(x2,y2,z2,c='g' ,marker='o')
ax.scatter(x3,y3,z3,c='r' ,marker='o')
ax.scatter(x4,y4,z4,c='pink' ,marker='o')
ax.scatter(x5,y5,z5,c='orange' ,marker='o')
ax.scatter(x6,y6,z6,c='yellow' ,marker='o')
ax.scatter(x7,y7,z7,c='purple' ,marker='o')
ax.scatter(x8,y8,z8,c='black' ,marker='o')
ax.scatter(x9,y9,z9,c='magenta' ,marker='o')
plt.show()

# %%
datos=np.loadtxt('1.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos[:,0:1]
y=datos[:,1:2]
z=datos[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('1')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos2=np.loadtxt('2.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos2[:,0:1]
y=datos2[:,1:2]
z=datos2[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)
plt.title('1')
ax.scatter(x,y,z, c='red', marker='o')
plt.show()

# %%
datos3=np.loadtxt('3.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos3[:,0:1]
y=datos3[:,1:2]
z=datos3[:,2:3]

plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)
ax.set_zlim(0, 5e12)
plt.title('3')
plt.xlabel('x')
plt.ylabel('y')
ax.scatter(x,y,z, c='r', marker='o')
plt.show()

# %%
datos4=np.loadtxt('4.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos4[:,0:1]
y=datos4[:,1:2]
z=datos4[:,2:3]


plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)
plt.title('4')
ax.scatter(x,y,z, c='red', marker='o')
plt.show()

# %%
datos5=np.loadtxt('5.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos5[:,0:1]
y=datos5[:,1:2]
z=datos5[:,2:3]

plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)
plt.title('5')
ax.scatter(x,y,z, c='red', marker='o')
plt.show()

# %%
datos6=np.loadtxt('6.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos6[:,0:1]
y=datos6[:,1:2]
z=datos6[:,2:3]

plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)

plt.title('6')
ax.scatter(x,y,z, c='red', marker='o')
plt.show()

# %%
datos7=np.loadtxt('7.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos7[:,0:1]
y=datos7[:,1:2]
z=datos7[:,2:3]
plt.xlim(1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)
plt.title('7')
ax.scatter(x,y,z, c='red', marker='o')
plt.show()

# %%
datos8=np.loadtxt('8.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x=datos8[:,0:1]
y=datos8[:,1:2]
z=datos8[:,2:3]
plt.xlim(1e8,6e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)
plt.title('8')
ax.scatter(x,y,z, c='red', marker='o')
plt.show()

# %%
datos9=np.loadtxt('9.txt')

# %%
fig=plt.figure()

fig = plt.figure()
ax= Axes3D(fig)
x9=datos9[:,0:1]
y9=datos9[:,1:2]
z9=datos9[:,2:3]
plt.xlim(-1e8,8e12)
plt.ylim(0,1.5e11) # Limitamos los valores del eje x 
ax.set_zlim(0, 5e11)
plt.title('9')
ax.scatter(x9,y9,z9, c='red', marker='o')
plt.show()
